# %% [markdown]
# # 📊 Sales Data Analysis for a Retail Company
# This project analyzes one year of fictional sales data for a retail company. It includes trends, visualizations, and insights for business decision-making.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')
# %matplotlib inline

# %%
df = pd.read_csv('sales_data.csv')
df.head()
# Out:
#    Order ID     Product  Quantity Ordered  Price Each         City  \
# 0      1001     Monitor                 4      763.81  Los Angeles
# 1      1002    Keyboard                 4      870.85     New York
# 2      1003  Headphones                 4     1159.77  Los Angeles
# 3      1004    Keyboard                 1       94.10      Chicago
# 4      1005    Keyboard                 4     1491.99  Los Angeles
#
#    Order Date Month    Sales
# 0  2023-04-21   Apr  3055.24
# 1  2023-09-06   Sep  3483.40
# 2  2023-05-31   May  4639.08
# 3  2023-07-02   Jul    94.10
# 4  2023-12-02   Dec  5967.96

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          200 non-null    int64
#  1   Product           200 non-null    object
#  2   Quantity Ordered  200 non-null    int64
#  3   Price Each        200 non-null    float64
#  4   City              200 non-null    object
#  5   Order Date        200 non-null    object
#  6   Month             200 non-null    object
#  7   Sales             200 non-null    float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 12.6+ KB

# %%
# Total sales per month
monthly_sales = df.groupby('Month')['Sales'].sum().reindex(
    ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
)
monthly_sales.plot(kind='bar', figsize=(10,6), color='skyblue')
plt.title('Total Sales by Month')
plt.ylabel('Revenue ($)')
plt.xlabel('Month')
plt.xticks(rotation=45)
plt.show()

# %%
# Total sales by city
city_sales = df.groupby('City')['Sales'].sum().sort_values(ascending=False)
city_sales.plot(kind='bar', figsize=(10,6), color='orange')
plt.title('Sales by City')
plt.ylabel('Revenue ($)')
plt.xticks(rotation=45)
plt.show()

# %%
# Top-selling products
product_sales = df.groupby('Product')['Sales'].sum().sort_values(ascending=False)
product_sales.plot(kind='bar', figsize=(10,6), color='green')
plt.title('Sales by Product')
plt.ylabel('Revenue ($)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 📌 Key Insights
# - **Highest revenue month**: Easily visible from the bar chart
# - **Top city**: Best-performing location for the year
# - **Best-selling product**: Focus for future marketing or bundling
# - This analysis provides a foundation for data-driven decision making.
